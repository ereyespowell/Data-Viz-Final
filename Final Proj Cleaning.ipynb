# %%
import pandas as pd

# %%
whr_df = pd.read_excel('WHR.xlsx')

# %%
whr_df.head()
# Out:
#    Year  Rank Country name  Life evaluation (3-year average)  Lower whisker  \
# 0  2025     1      Finland                             7.764          7.690
# 1  2025     2      Iceland                             7.540          7.449
# 2  2025     3      Denmark                             7.539          7.446
# 3  2025     4   Costa Rica                             7.439          7.356
# 4  2025     5       Sweden                             7.255          7.172
#
#    Upper whisker  Explained by: Log GDP per capita  \
# 0          7.837                             1.915
# 1          7.630                             1.971
# 2          7.631                             1.986
# 3          7.522                             1.697
# 4          7.337                             1.950
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.638                                  0.939
# ...

# %%
whr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2116 entries, 0 to 2115
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Year                                        2116 non-null   int64
#  1   Rank                                        2116 non-null   int64
#  2   Country name                                2116 non-null   object
#  3   Life evaluation (3-year average)            2116 non-null   float64
#  4   Lower whisker                               1022 non-null   float64
#  5   Upper whisker                               1022 non-null   float64
#  6   Explained by: Log GDP per capita            1019 non-null   float64
#  7   Explained by: Social support                1019 non-null   float64
#  8   Explained by: Healthy life expectancy       1016 non-null   float64
# ...

# %%
whr_df.dropna(subset=['Lower whisker'], inplace=True)

# %%
whr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1022 entries, 0 to 1021
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Year                                        1022 non-null   int64
#  1   Rank                                        1022 non-null   int64
#  2   Country name                                1022 non-null   object
#  3   Life evaluation (3-year average)            1022 non-null   float64
#  4   Lower whisker                               1022 non-null   float64
#  5   Upper whisker                               1022 non-null   float64
#  6   Explained by: Log GDP per capita            1019 non-null   float64
#  7   Explained by: Social support                1019 non-null   float64
#  8   Explained by: Healthy life expectancy       1016 non-null   float64
#  9   Explained by: Freedom to make life choices  1017 non-null   float64
# ...

# %%
whr_df.value_counts('Country name')
# Out:
# Country name
# Afghanistan                 7
# Kyrgyzstan                  7
# Myanmar                     7
# Namibia                     7
# Nepal                       7
#                            ..
# Haiti                       2
# Maldives                    2
# Burundi                     2
# Central African Republic    1
# South Sudan                 1
# Name: count, Length: 157, dtype: int64

# %%
whr_df.describe()
# Out:
#               Year         Rank  Life evaluation (3-year average)  \
# count  1022.000000  1022.000000                       1022.000000
# mean   2021.975538    73.573386                          5.550427
# std       2.021527    42.291651                          1.123618
# min    2019.000000     1.000000                          1.364000
# 25%    2020.000000    37.000000                          4.745650
# 50%    2022.000000    73.500000                          5.705000
# 75%    2024.000000   110.000000                          6.377775
# max    2025.000000   153.000000                          7.842000
#
#        Lower whisker  Upper whisker  Explained by: Log GDP per capita  \
# count    1022.000000    1022.000000                       1019.000000
# mean        5.436091       5.664733                          1.265670
# std         1.140959       1.107424                          0.463823
# min         1.301000       1.427000                          0.000000
# ...

# %%
country_counts = whr_df["Country name"].value_counts()

# %%
whr_filtered = whr_df[whr_df["Country name"].isin(country_counts[country_counts >= 7].index)]

# %%
whr_filtered.value_counts('Country name')
# Out:
# Country name
# Afghanistan    7
# Norway         7
# Netherlands    7
# New Zealand    7
# Nicaragua      7
#               ..
# France         7
# Finland        7
# Ethiopia       7
# Estonia        7
# Zimbabwe       7
# Name: count, Length: 136, dtype: int64

# %%
whr_filtered.to_excel("whr_cleaned.xlsx", index=False)
